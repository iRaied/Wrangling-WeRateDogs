# %% [markdown]
# # Wrangling, Analyzing, and Visualizing WeRateDogs Tweets

# %% [markdown]
# ## Gather
# 1. We have given the data in a CSV file `twitter-archive-enhanced.csv`
# <br></br>
# 2. We should gather additional data via `Twitter API` for (retweets count and likes count)
# <br></br>
# 3. Image predictions it is a file hosted in a webpage. We need to daownload it programmatically using `Requests` library

# %%
import pandas as pd
import numpy as np
import json
import requests
import io

# %%
archive = pd.read_csv('twitter-archive-enhanced.csv')

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# %%
urlData = requests.get(url).content
image_prediction = pd.read_csv(io.StringIO(urlData.decode('utf-8')), sep='\t')

# %%
tweet_details = pd.DataFrame(columns=['tweet_id', 'retweet_count', 'favorite_count'])
with open('tweet-json.txt') as f:
    for line in f:
        status  = json.loads(line)
        tweet_id = status['id_str']
        retweet_count = status['retweet_count']
        favorite_count = status['favorite_count']
        tweet_details = tweet_details .append(pd.DataFrame([[tweet_id, retweet_count, favorite_count]],
                                        columns=['tweet_id', 'retweet_count', 'favorite_count']))
tweet_details = tweet_details .reset_index(drop=True)

# %% [markdown]
# ### Twitter API
# Does not work

# %% [markdown]
# ## Assess

# %%
# Let's assess archive table visually
archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
# Let's assess archive table programmatically 
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
# What is the column in_reply_to_status_is for
archive[archive['in_reply_to_status_id'].notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 149   863079547188785154           6.671522e+17         4.196984e+09
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 184   856526610513747968           8.558181e+17         4.196984e+09
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# ...

# %%
# What is the column retweeted_status_id for
archive[archive['retweeted_status_id'].notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# 74    878316110768087041                    NaN                  NaN
# 78    877611172832227328                    NaN                  NaN
# 91    874434818259525634                    NaN                  NaN
# 95    873697596434513921                    NaN                  NaN
# 97    873337748698140672                    NaN                  NaN
# 101   872668790621863937                    NaN                  NaN
# 109   871166179821445120                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# ...

# %%
# Check for duplicate in tweet_id
archive[archive.tweet_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# Check for duplicate in expanded_urls
archive[archive.expanded_urls.duplicated()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 75    878281511006478336                    NaN                  NaN
# 76    878057613040115712                    NaN                  NaN
# 98    873213775632977920                    NaN                  NaN
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 126   868552278524837888                    NaN                  NaN
# 135   866450705531457537                    NaN                  NaN
# 136   866334964761202691                    NaN                  NaN
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 150   863062471531167744                    NaN                  NaN
# 161   860563773140209665                    NaN                  NaN
# 169   859196978902773760                    NaN                  NaN
# ...

# %%
archive.query('expanded_urls == "https://www.gofundme.com/3yd6y1c,https://twitter.com/dog_rates/status/878281511006478336/photo/1"')
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 73  878404777348136964                    NaN                  NaN
# 75  878281511006478336                    NaN                  NaN
#
#                     timestamp  \
# 73  2017-06-24 00:09:53 +0000
# 75  2017-06-23 16:00:04 +0000
#
#                                                source  \
# 73  <a href="http://twitter.com/download/iphone" r...
# 75  <a href="http://twitter.com/download/iphone" r...
#
#                                                  text  retweeted_status_id  \
# 73  RT @dog_rates: Meet Shadow. In an attempt to r...         8.782815e+17
# 75  Meet Shadow. In an attempt to reach maximum zo...                  NaN
#
#     retweeted_status_user_id retweeted_status_timestamp  \
# 73              4.196984e+09  2017-06-23 16:00:04 +0000
# 75                       NaN                        NaN
#
#                                         expanded_urls  rating_numerator  \
# ...

# %%
archive.query('expanded_urls == "https://vine.co/v/ea0OwvPTx9l"')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 657   791774931465953280                    NaN                  NaN
# 2212  668587383441514497                    NaN                  NaN
#
#                       timestamp  \
# 657   2016-10-27 22:53:48 +0000
# 2212  2015-11-23 00:30:28 +0000
#
#                                                  source  \
# 657   <a href="http://vine.co" rel="nofollow">Vine -...
# 2212  <a href="http://vine.co" rel="nofollow">Vine -...
#
#                                                    text  retweeted_status_id  \
# 657   Vine will be deeply missed. This was by far my...                  NaN
# 2212  Never forget this vine. You will not stop watc...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 657                        NaN                        NaN
# 2212                       NaN                        NaN
#
# ...

# %%
# What is the not null value(s) of column doggo
archive[archive['doggo']!= 'None']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 9     890240255349198849                    NaN                  NaN
# 43    884162670584377345                    NaN                  NaN
# 99    872967104147763200                    NaN                  NaN
# 108   871515927908634625                    NaN                  NaN
# 110   871102520638267392                    NaN                  NaN
# 121   869596645499047938                    NaN                  NaN
# 172   858843525470990336                    NaN                  NaN
# 191   855851453814013952                    NaN                  NaN
# 200   854010172552949760                    NaN                  NaN
# 211   851953902622658560                    NaN                  NaN
# 240   846514051647705089                    NaN                  NaN
# 248   845397057150107648                    NaN                  NaN
# 300   836753516572119041                    NaN                  NaN
# ...

# %%
# What is the not null value(s) of column doggo
archive.doggo.unique()
# Out:
# array(['None', 'doggo'], dtype=object)

# %%
# How many values in column rating_numerator
archive.rating_numerator.unique()
# Out:
# array([  13,   12,   14,    5,   17,   11,   10,  420,  666,    6,   15,
#         182,  960,    0,   75,    7,   84,    9,   24,    8,    1,   27,
#           3,    4,  165, 1776,  204,   50,   99,   80,   45,   60,   44,
#         143,  121,   20,   26,    2,  144,   88])

# %%
# what does the rating_denominator have if rating_denominator = 170
archive[archive['rating_denominator'] == 170]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1120  731156023742988288                    NaN                  NaN
#
#                       timestamp  \
# 1120  2016-05-13 16:15:54 +0000
#
#                                                  source  \
# 1120  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1120  Say hello to this unbelievably well behaved sq...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1120                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1120  https://twitter.com/dog_rates/status/731156023...               204
#
#       rating_denominator  name doggo floofer pupper puppo
# 1120                 170  this  None    None   None  None

# %%
# How many different value are there in rating_numerator column
archive['rating_numerator'].value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
# How many different values in rating_denominator column
archive.rating_denominator.unique()
# Out:
# array([ 10,   0,  15,  70,   7,  11, 150, 170,  20,  50,  90,  80,  40,
#        130, 110,  16, 120,   2])

# %%
# Let's count the number of different values
archive.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
archive.name.value_counts()
# Out:
# None        745
# a            55
# Charlie      12
# Lucy         11
# Oliver       11
# Cooper       11
# Tucker       10
# Penny        10
# Lola         10
# Winston       9
# Bo            9
# the           8
# Sadie         8
# an            7
# Bailey        7
# Toby          7
# Buddy         7
# Daisy         7
# Dave          6
# Stanley       6
# Koda          6
# Bella         6
# Scout         6
# Milo          6
# Rusty         6
# Jax           6
# Oscar         6
# Leo           6
# Jack          6
# George        5
#            ...
# Darby         1
# Fwed          1
# Ridley        1
# Nugget        1
# Corey         1
# Blanket       1
# Timofy        1
# Hermione      1
# Gustaf        1
# Tess          1
# Lugan         1
# Autumn        1
# Boots         1
# Ralph         1
# Akumi         1
# Ester         1
# Tedders       1
# Jomathan      1
# Molly         1
# Brudge        1
# Norman        1
# Livvie        1
# Tuco          1
# Simba         1
# ...

# %%
# How many rows having one stage "doggo or floofer or pupper or puppo"
archive.query('doggo == "doggo" or floofer =="floofer" or pupper == "pupper" or puppo == "puppo"').tweet_id.count()
# Out:
# 380

# %%
archive.name.value_counts()
# Out:
# None        745
# a            55
# Charlie      12
# Lucy         11
# Oliver       11
# Cooper       11
# Tucker       10
# Penny        10
# Lola         10
# Winston       9
# Bo            9
# the           8
# Sadie         8
# an            7
# Bailey        7
# Toby          7
# Buddy         7
# Daisy         7
# Dave          6
# Stanley       6
# Koda          6
# Bella         6
# Scout         6
# Milo          6
# Rusty         6
# Jax           6
# Oscar         6
# Leo           6
# Jack          6
# George        5
#            ...
# Darby         1
# Fwed          1
# Ridley        1
# Nugget        1
# Corey         1
# Blanket       1
# Timofy        1
# Hermione      1
# Gustaf        1
# Tess          1
# Lugan         1
# Autumn        1
# Boots         1
# Ralph         1
# Akumi         1
# Ester         1
# Tedders       1
# Jomathan      1
# Molly         1
# Brudge        1
# Norman        1
# Livvie        1
# Tuco          1
# Simba         1
# ...

# %%
# View the name of columns to describe what each one of them contains
list(archive)
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %% [markdown]
# `archive` columns:
# - **'tweet_id'**: the unique identifier for each tweet. And it is the last part in the tweet's url
# - **'in_reply_to_status_id'**: Nullable. If the represented Tweet is a reply, this field will contain the integer representation of the original Tweet’s ID
# - **'in_reply_to_user_id'**: Nullable. If the represented Tweet is a reply, this field will contain the integer representation of the original Tweet’s author ID. This will not necessarily always be the user directly mentioned in the Tweet.
# - **'timestamp'**: This will contain the tweet date & time
# - **'source'**: Utility used to post the Tweet, as an HTML-formatted string. Tweets from the Twitter website have a source value of web.
# - **'text'**: The actual UTF-8 text of the status update. See twitter-text for details on what characters are currently considered valid.
# - **'retweeted_status_id'**: This will be not null if the tweet is a retweeted tweet, and it will contain the tweet's id
# - **'retweeted_status_user_id'**: This will be not null if the tweet is a retweeted tweet, and it will contain the tweet's user id
# - **'retweeted_status_timestamp'**: This will be not null if the tweet is a retweeted tweet, and it will contain the tweet's date & time
# - **'expanded_urls'**: The full link for the tweet
# - **'rating_numerator'**: Rating value Numerator will be one of these values [13, 12, 14, 5, 17, 11, 10, 420, 666, 6, 15, 182, 960, 0, 75, 7, 84, 9, 24, 8, 1, 27, 3, 4, 165, 1776, 204, 50, 99, 80, 45, 60, 44, 143, 121, 20, 26, 2, 144, 88]
# - **'rating_denominator'**: Rating value Denominator will be one of these values [10, 0,15, 70, 7, 11, 150, 170, 20, 50, 90, 80, 40, 130, 110, 16, 120, 2]
# - **'name'**: Dog Name
# - **'doggo'**: Dog Stage, and its value either ['None', 'doggo']. Note: None is a text not NaN.
# - **'floofer'**: Dog Stage, and its value either ['None', 'floofer']. Note: None is a text not NaN.
# - **'pupper'**: Dog Stage, and its value either ['None', 'pupper']. Note: None is a text not NaN.
# - **'puppo'**: Dog Stage, and its value either ['None', 'puppo']. Note: None is a text not NaN.

# %%
# Let's assess tweet_details table visually
tweet_details
# Out:
#                 tweet_id retweet_count favorite_count
# 0     892420643555336193          8853          39467
# 1     892177421306343426          6514          33819
# 2     891815181378084864          4328          25461
# 3     891689557279858688          8964          42908
# 4     891327558926688256          9774          41048
# 5     891087950875897856          3261          20562
# 6     890971913173991426          2158          12041
# 7     890729181411237888         16716          56848
# 8     890609185150312448          4429          28226
# 9     890240255349198849          7711          32467
# 10    890006608113172480          7624          31166
# 11    889880896479866881          5156          28268
# 12    889665388333682689          8538          38818
# 13    889638837579907072          4735          27672
# 14    889531135344209921          2321          15359
# 15    889278841981685760          5637          25652
# ...

# %%
# Let's assess archive table programmically
tweet_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null object
# retweet_count     2354 non-null object
# favorite_count    2354 non-null object
# dtypes: object(3)
# memory usage: 55.2+ KB

# %%
tweet_details[tweet_details.tweet_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, retweet_count, favorite_count]
# Index: []

# %%
# describe function does not work because of the type of columns
tweet_details.describe()
# Out:
#                   tweet_id  retweet_count  favorite_count
# count                 2354           2354            2354
# unique                2354           1724            2007
# top     667878741721415682           3652               0
# freq                     1              5             179

# %%
# Let's assess image_prediction table visually
image_prediction
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
image_prediction[image_prediction['p1'].str.match('s')].p1.value_counts()
# Out:
# seat_belt                      22
# soft-coated_wheaten_terrier    11
# schipperke                     10
# standard_poodle                 8
# swing                           7
# shopping_cart                   5
# space_heater                    3
# ski_mask                        3
# sea_lion                        3
# seashore                        3
# stone_wall                      3
# shower_curtain                  2
# street_sign                     2
# sorrel                          2
# snorkel                         2
# snail                           2
# soccer_ball                     1
# skunk                           1
# swab                            1
# silky_terrier                   1
# standard_schnauzer              1
# shopping_basket                 1
# snowmobile                      1
# sandbar                         1
# starfish                        1
# suit                            1
# sulphur-crested_cockatoo        1
# ...

# %%
image_prediction[image_prediction['p1'].str.match('S')].p1.value_counts()
# Out:
# Samoyed                      43
# Siberian_husky               20
# Staffordshire_bullterrier    20
# Shetland_sheepdog            18
# Shih-Tzu                     17
# Siamese_cat                   7
# Saint_Bernard                 7
# Saluki                        4
# Scottish_deerhound            3
# Sussex_spaniel                2
# Scotch_terrier                1
# Name: p1, dtype: int64

# %%
# is there any image has the same breed prediction with different values of p1, p2, and p3
image_prediction.query('p1 == p2 or p1 == p3 or p2 == p3')
# Out:
#                 tweet_id                                          jpg_url  \
# 1409  770414278348247044  https://pbs.twimg.com/media/CrEPsfWXEAAKvem.jpg
#
#       img_num       p1   p1_conf  p1_dog       p2   p2_conf  p2_dog  \
# 1409        1  maillot  0.580528   False  maillot  0.081449   False
#
#                     p3  p3_conf  p3_dog
# 1409  golden_retriever  0.05357    True

# %%
# is p1_conf the most prediction value 
image_prediction.query('p1_conf > p2_conf and p1_conf > p3_conf').count()[0]
# Out:
# 2075

# %%
image_prediction.query('img_num == 4')
# Out:
#                 tweet_id                                          jpg_url  \
# 144   668623201287675904  https://pbs.twimg.com/media/CUdtP1xUYAIeBnE.jpg
# 779   689905486972461056  https://pbs.twimg.com/media/CZMJYCRVAAE35Wk.jpg
# 1024  710588934686908417  https://pbs.twimg.com/media/CdyE2x1W8AAe0TG.jpg
# 1161  734787690684657664  https://pbs.twimg.com/media/CjJ9gQ1WgAAXQtJ.jpg
# 1286  750868782890057730  https://pbs.twimg.com/media/CmufLLsXYAAsU0r.jpg
# 1325  756998049151549440  https://pbs.twimg.com/media/CoFlsGAWgAA2YeV.jpg
# 1337  758405701903519748  https://pbs.twimg.com/media/CoZl9fXWgAMox0n.jpg
# 1342  758854675097526272  https://pbs.twimg.com/media/Cof-SuqVYAAs4kZ.jpg
# 1372  762464539388485633  https://pbs.twimg.com/media/CpTRc4DUEAAYTq6.jpg
# 1437  773985732834758656  https://pbs.twimg.com/media/Cr2_6R8WAAAUMtc.jpg
# 1496  783391753726550016  https://pbs.twimg.com/media/Ct8qn8EWIAAk9zP.jpg
# 1542  791312159183634433  https://pbs.twimg.com/media/CvtONV4WAAAQ3Rn.jpg
# ...

# %%
# Let's assess image_prediction table programmatically 
image_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
# View the name of columns to describe what each one of them contains
list(image_prediction)
# Out:
# ['tweet_id',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog']

# %% [markdown]
# `image_prediction` columns:
# <br></br>
# - **tweet_id**: is the last part of the tweet URL after "status/"
# - **jpg_url**: is the link for the image used in the algorithms
# - **img_num**: is the image number that corresponded to the most confident prediction (numbered 1 to 4 since tweets can have up to four images)
# - **p1**: is the algorithm's #1 prediction for the image in the tweet
# - **p1_conf**: is how confident the algorithm is in its #1 prediction
# - **p1_dog**: is whether or not the #1 prediction is a breed of dog
# - **p2**: is the algorithm's second most likely prediction
# - **p2_conf**: is how confident the algorithm is in its #2 prediction
# - **p2_dog**: is whether or not the #2 prediction is a breed of dog
# - **p3**: is the algorithm's third most likely prediction
# - **p3_conf**: is how confident the algorithm is in its #3 prediction
# - **p3_dog**: is whether or not the #3 prediction is a breed of dog

# %%
# Let's see if there are duplicated values based on jpg_url
image_prediction[image_prediction.jpg_url.duplicated()]
# Out:
#                 tweet_id                                            jpg_url  \
# 1297  752309394570878976  https://pbs.twimg.com/ext_tw_video_thumb/67535...
# 1315  754874841593970688    https://pbs.twimg.com/media/CWza7kpWcAAdYLc.jpg
# 1333  757729163776290825    https://pbs.twimg.com/media/CWyD2HGUYAQ1Xa7.jpg
# 1345  759159934323924993    https://pbs.twimg.com/media/CU1zsMSUAAAS0qW.jpg
# 1349  759566828574212096    https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg
# 1364  761371037149827077  https://pbs.twimg.com/tweet_video_thumb/CeBym7...
# 1368  761750502866649088    https://pbs.twimg.com/media/CYLDikFWEAAIy1y.jpg
# 1387  766078092750233600    https://pbs.twimg.com/media/ChK1tdBWwAQ1flD.jpg
# 1407  770093767776997377    https://pbs.twimg.com/media/CkjMx99UoAM2B1a.jpg
# 1417  771171053431250945    https://pbs.twimg.com/media/CVgdFjNWEAAxmbq.jpg
# 1427  772615324260794368    https://pbs.twimg.com/media/Cp6db4-XYAAMmqL.jpg
# ...

# %%
# How many tweets have 1, 2, 3, 4 images ? 
image_prediction.img_num.value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
# Let's see how many different values in p1
image_prediction.p1.value_counts()
# Out:
# golden_retriever             150
# Labrador_retriever           100
# Pembroke                      89
# Chihuahua                     83
# pug                           57
# chow                          44
# Samoyed                       43
# toy_poodle                    39
# Pomeranian                    38
# cocker_spaniel                30
# malamute                      30
# French_bulldog                26
# miniature_pinscher            23
# Chesapeake_Bay_retriever      23
# seat_belt                     22
# German_shepherd               20
# Siberian_husky                20
# Staffordshire_bullterrier     20
# Cardigan                      19
# web_site                      19
# Eskimo_dog                    18
# Shetland_sheepdog             18
# Maltese_dog                   18
# beagle                        18
# teddy                         18
# Shih-Tzu                      17
# Lakeland_terrier              17
# Rottweiler                    17
# ...

# %% [markdown]
# #### Qualtiy
# ##### archive table:
# - Missing data in columns `doggo`,`floofer`,`pupper`,`puppo` wroted as None
# - Missing data, there are 78 rows as replys and not tweets, find it via columns not null for `in_reply_to_status_id`, `in_reply_to_user_id`
# - Missing data, there are 181 rows as retweets, find it via columns not null for `retweeted_status_id`, `retweeted_status_user_id`, `retweeted_status_timestamp`
# - Missing data, there are 2297 instead of 2356 in column `expanded_urls`
# - `name` column has some values like 'a', 'an', 'the', 'None'
# - Duplicated `expanded_urls`
# - `tweet_id` column type is `int64` not `string`
# - `timestamp` column type is `object`
# - Incorrect values in `rating_numerators`
#
# ##### tweet_details table:
# - There are 2354 instead of 2356 (number of records in archive table)
# - `retweet_count` column type is `object`
# - `favorite_count` column type is `object`
#
# ##### image_prediction table:
# - There are 2075 instead of 2356 (number of records in archive table)
# - Uppercase, Lowercase, and underscores in each words in columns p1, p2, p3
# - Duplicated `jpg_url`
# - `tweet_id` column type is `int64` not `string`

# %% [markdown]
# #### Tidiness
#
# - archive table should be merged with tweet_details table
#
# ##### archive table:
#
# - four variables in four columns `doggo`,`floofer`,`pupper`,`puppo`
#
# ##### tweet_details table:
#
#
#
# ##### image_prediction table:

# %% [markdown]
# ### Clean

# %%
archive_copy = archive.copy()
tweet_details_copy = tweet_details.copy()
image_prediction_copy = image_prediction.copy()

# %% [markdown]
# #### Missing Data

# %% [markdown]
# **`archive`: Missing data, there are 78 rows as replys and not tweets, find it via columns not null for `in_reply_to_status_id`, `in_reply_to_user_id`**

# %% [markdown]
# #### Define
# * Drop the 78 rows from the dataset then drop the columns `in_reply_to_status_id`, `in_reply_to_user_id`

# %% [markdown]
# #### Code

# %%
# Store the indexes in idx then use them to drop all rows
idx = archive_copy[archive_copy['in_reply_to_status_id'].notnull()].index
archive_copy.drop(idx, axis=0, inplace=True)

# %% [markdown]
# #### Test

# %%
# Should be no rows
archive_copy[archive_copy['in_reply_to_status_id'].notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# Should be no rows
archive_copy[archive_copy['in_reply_to_user_id'].notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# #### Code

# %%
# Then, drop the columns
archive_copy.drop(columns=['in_reply_to_status_id', 'in_reply_to_user_id'], inplace=True)

# %% [markdown]
# #### Test

# %%
# Columns should be removed
list(archive_copy)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %% [markdown]
# **`archive`: Missing data, there are 181 rows as retweets, find it via columns not null for `retweeted_status_id`, `retweeted_status_user_id`, `retweeted_status_timestamp`**

# %% [markdown]
# #### Define
# * Drop the 181 rows from the dataset then drop the columns `retweeted_status_id`, `retweeted_status_user_id`, `retweeted_status_timestamp`

# %% [markdown]
# #### Code

# %%
# Store the indexes in idx then use them to drop all rows
idx = archive_copy[archive_copy['retweeted_status_id'].notnull()].index
archive_copy.drop(idx, axis=0, inplace=True)

# %% [markdown]
# #### Test

# %%
# Should be no rows
archive_copy[archive_copy['retweeted_status_id'].notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# Should be no rows
archive_copy[archive_copy['retweeted_status_user_id'].notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# Should be no rows
archive_copy[archive_copy['retweeted_status_timestamp'].notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# #### Code

# %%
# Then, drop the columns
archive_copy.drop(columns=['retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'], inplace=True)

# %% [markdown]
# #### Test

# %%
# Columns should be removed
list(archive_copy)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %% [markdown]
# **`archive`: Missing data, there are 2297 instead of 2356 in column `expanded_urls`**

# %%
# Let's see the new numbers after we dropped some rows
archive_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2097 non-null int64
# timestamp             2097 non-null object
# source                2097 non-null object
# text                  2097 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2097 non-null int64
# rating_denominator    2097 non-null int64
# name                  2097 non-null object
# doggo                 2097 non-null object
# floofer               2097 non-null object
# pupper                2097 non-null object
# puppo                 2097 non-null object
# dtypes: int64(3), object(9)
# memory usage: 213.0+ KB

# %%
# So, there are 3 rows having expanded_urls NaN value
# Let's display them
archive_copy[archive_copy['expanded_urls'].isnull()]
# Out:
#                 tweet_id                  timestamp  \
# 375   828361771580813312  2017-02-05 21:56:51 +0000
# 707   785515384317313025  2016-10-10 16:20:36 +0000
# 1445  696518437233913856  2016-02-08 02:18:30 +0000
#
#                                                  source  \
# 375   <a href="http://twitter.com" rel="nofollow">Tw...
# 707   <a href="http://twitter.com/download/iphone" r...
# 1445  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text expanded_urls  \
# 375   Beebop and Doobert should start a band 12/10 w...           NaN
# 707      Today, 10/10, should be National Dog Rates Day           NaN
# 1445    Oh my god 10/10 for every little hot dog pupper           NaN
#
#       rating_numerator  rating_denominator  name doggo floofer  pupper puppo
# 375                 12                  10  None  None    None    None  None
# 707                 10                  10  None  None    None    None  None
# ...

# %% [markdown]
# #### Define
# * Go to each link manually on the browser, if tweets are there with no issues, fill these rows manually, otherwise drop them

# %% [markdown]
# - After checking manually, These tweets exist but they don't have images 828361771580813312 , 785515384317313025 , 696518437233913856 , So we will drop them

# %% [markdown]
# #### Code

# %%
# Store thier indexes
idx = archive_copy[archive_copy['expanded_urls'].isnull()].index
archive_copy.drop(idx, axis=0, inplace=True)

# %% [markdown]
# #### Test

# %%
# Should be no rows
archive_copy[archive_copy['expanded_urls'].isnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
archive_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2094 non-null int64
# timestamp             2094 non-null object
# source                2094 non-null object
# text                  2094 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2094 non-null int64
# rating_denominator    2094 non-null int64
# name                  2094 non-null object
# doggo                 2094 non-null object
# floofer               2094 non-null object
# pupper                2094 non-null object
# puppo                 2094 non-null object
# dtypes: int64(3), object(9)
# memory usage: 212.7+ KB

# %% [markdown]
# #### Duplicated Rows
# **`archive`: Duplicated `expanded_urls`**

# %% [markdown]
# #### Define
# * Remove duplicated expanded_urls rows

# %% [markdown]
# #### Code

# %%
# Display the duplicated rows
archive_copy[archive_copy.expanded_urls.duplicated()]
# Out:
#                 tweet_id                  timestamp  \
# 2212  668587383441514497  2015-11-23 00:30:28 +0000
#
#                                                  source  \
# 2212  <a href="http://vine.co" rel="nofollow">Vine -...
#
#                                                    text  \
# 2212  Never forget this vine. You will not stop watc...
#
#                       expanded_urls  rating_numerator  rating_denominator  \
# 2212  https://vine.co/v/ea0OwvPTx9l                13                  10
#
#      name doggo floofer pupper puppo
# 2212  the  None    None   None  None

# %%
# Get the indexes
archive_copy.query('expanded_urls == "https://vine.co/v/ea0OwvPTx9l"')
# Out:
#                 tweet_id                  timestamp  \
# 657   791774931465953280  2016-10-27 22:53:48 +0000
# 2212  668587383441514497  2015-11-23 00:30:28 +0000
#
#                                                  source  \
# 657   <a href="http://vine.co" rel="nofollow">Vine -...
# 2212  <a href="http://vine.co" rel="nofollow">Vine -...
#
#                                                    text  \
# 657   Vine will be deeply missed. This was by far my...
# 2212  Never forget this vine. You will not stop watc...
#
#                       expanded_urls  rating_numerator  rating_denominator  \
# 657   https://vine.co/v/ea0OwvPTx9l                14                  10
# 2212  https://vine.co/v/ea0OwvPTx9l                13                  10
#
#       name doggo floofer pupper puppo
# 657   None  None    None   None  None
# 2212   the  None    None   None  None

# %%
# Remove the most recent one based on timestamp
archive_copy.drop(index=657, axis=0, inplace=True)

# %% [markdown]
# #### Test

# %%
# Should be one row
archive_copy.query('expanded_urls == "https://vine.co/v/ea0OwvPTx9l"')
# Out:
#                 tweet_id                  timestamp  \
# 2212  668587383441514497  2015-11-23 00:30:28 +0000
#
#                                                  source  \
# 2212  <a href="http://vine.co" rel="nofollow">Vine -...
#
#                                                    text  \
# 2212  Never forget this vine. You will not stop watc...
#
#                       expanded_urls  rating_numerator  rating_denominator  \
# 2212  https://vine.co/v/ea0OwvPTx9l                13                  10
#
#      name doggo floofer pupper puppo
# 2212  the  None    None   None  None

# %%
# Should be no rows
archive_copy[archive_copy.expanded_urls.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# **`image_prediction`: Duplicated `jpg_url`**

# %% [markdown]
# #### Define
# * Remove duplicated jpg_url rows

# %% [markdown]
# #### Code

# %%
# Store their indexes, then drop rows
idx = image_prediction_copy[image_prediction_copy.jpg_url.duplicated()].index
image_prediction_copy.drop(idx, axis=0, inplace=True)

# %% [markdown]
# #### Test

# %%
# Should be no rows
image_prediction_copy[image_prediction_copy.jpg_url.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
# Should display one record
image_prediction_copy.query('jpg_url == "https://pbs.twimg.com/ext_tw_video_thumb/675354114423808004/pu/img/qL1R_nGLqa6lmkOx.jpg"')
# Out:
#                tweet_id                                            jpg_url  \
# 480  675354435921575936  https://pbs.twimg.com/ext_tw_video_thumb/67535...
#
#      img_num       p1   p1_conf  p1_dog                p2   p2_conf  p2_dog  \
# 480        1  upright  0.303415   False  golden_retriever  0.181351    True
#
#                    p3   p3_conf  p3_dog
# 480  Brittany_spaniel  0.162084    True

# %%
archive_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2093 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2093 non-null int64
# timestamp             2093 non-null object
# source                2093 non-null object
# text                  2093 non-null object
# expanded_urls         2093 non-null object
# rating_numerator      2093 non-null int64
# rating_denominator    2093 non-null int64
# name                  2093 non-null object
# doggo                 2093 non-null object
# floofer               2093 non-null object
# pupper                2093 non-null object
# puppo                 2093 non-null object
# dtypes: int64(3), object(9)
# memory usage: 212.6+ KB

# %%
tweet_details_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null object
# retweet_count     2354 non-null object
# favorite_count    2354 non-null object
# dtypes: object(3)
# memory usage: 55.2+ KB

# %%
image_prediction_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2009 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2009 non-null int64
# jpg_url     2009 non-null object
# img_num     2009 non-null int64
# p1          2009 non-null object
# p1_conf     2009 non-null float64
# p1_dog      2009 non-null bool
# p2          2009 non-null object
# p2_conf     2009 non-null float64
# p2_dog      2009 non-null bool
# p3          2009 non-null object
# p3_conf     2009 non-null float64
# p3_dog      2009 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 162.8+ KB

# %% [markdown]
# **`archive`: Missing data in columns `doggo`,`floofer`,`pupper`,`puppo` wroted as None**

# %% [markdown]
# #### Define
# * replace string None with NaN, no need to do any further thing

# %% [markdown]
# #### Code

# %%
# Replace None with NaN
archive_copy.replace('None', np.nan, inplace=True)

# %% [markdown]
# #### Test

# %%
# Check if there are NaN values
archive_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2093 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2093 non-null int64
# timestamp             2093 non-null object
# source                2093 non-null object
# text                  2093 non-null object
# expanded_urls         2093 non-null object
# rating_numerator      2093 non-null int64
# rating_denominator    2093 non-null int64
# name                  1494 non-null object
# doggo                 83 non-null object
# floofer               10 non-null object
# pupper                229 non-null object
# puppo                 24 non-null object
# dtypes: int64(3), object(9)
# memory usage: 212.6+ KB

# %% [markdown]
# **`archive`: `name` column has some values like 'a', 'an', 'the', 'None'**

# %% [markdown]
# #### Define
# * Replace these values with NaN

# %% [markdown]
# #### Code

# %%
# Replace a, an, the, None with NaN
archive_copy.name.replace(['a','an','the','None'], np.nan, inplace=True)

# %% [markdown]
# #### Test

# %%
# Should be no rows
archive_copy.query('name in ["a", "an", "the", "None"]')
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# #### Columns Types

# %% [markdown]
# **`archive`:**
# * `tweet_id` column type is `int64` not `string`
# * `timestamp` column type is `object`

# %% [markdown]
# #### Define
# * Change each column type

# %% [markdown]
# #### Code

# %%
# To string
archive_copy.tweet_id = archive_copy.tweet_id.astype(str)

# To datetime
archive_copy.timestamp = pd.to_datetime(archive_copy.timestamp)

# %% [markdown]
# #### Test

# %%
archive_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2093 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2093 non-null object
# timestamp             2093 non-null datetime64[ns]
# source                2093 non-null object
# text                  2093 non-null object
# expanded_urls         2093 non-null object
# rating_numerator      2093 non-null int64
# rating_denominator    2093 non-null int64
# name                  1425 non-null object
# doggo                 83 non-null object
# floofer               10 non-null object
# pupper                229 non-null object
# puppo                 24 non-null object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 212.6+ KB

# %% [markdown]
# **archive: Incorrect values in `rating_numerators`**

# %% [markdown]
# #### Define
# * Rating numerators have not been properly cleaned. The current pipeline captures incorrect values when rating numerators contain decimals. For example, here is a value from one observation with tweet id 786709082849828864 , Currently, the value 75 would be captured as the rating numerator. Try to capture the entire value from the text instead. Here is a code snippet as an example, where df here is the twitter archive dataset

# %% [markdown]
# #### Code

# %%
# Display the wrong rating_numerator
archive.query('tweet_id == "786709082849828864"')
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 695  786709082849828864                    NaN                  NaN
#
#                      timestamp  \
# 695  2016-10-13 23:23:56 +0000
#
#                                                 source  \
# 695  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 695  This is Logan, the Chow who lived. He solemnly...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 695                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 695  https://twitter.com/dog_rates/status/786709082...                75
#
#      rating_denominator   name doggo floofer pupper puppo
# 695                  10  Logan  None    None   None  None

# %%
archive.rating_numerator = archive.text.str.extract('((?:\d+\.)?\d+)\/')

# %% [markdown]
# #### Test

# %%
# Should be corrected
archive.query('tweet_id == "786709082849828864"')
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 695  786709082849828864                    NaN                  NaN
#
#                      timestamp  \
# 695  2016-10-13 23:23:56 +0000
#
#                                                 source  \
# 695  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 695  This is Logan, the Chow who lived. He solemnly...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 695                       NaN                        NaN
#
#                                          expanded_urls rating_numerator  \
# 695  https://twitter.com/dog_rates/status/786709082...             9.75
#
#      rating_denominator   name doggo floofer pupper puppo
# 695                  10  Logan  None    None   None  None

# %% [markdown]
# **tweet_details**:
# - `retweet_count` column type is `object`
# - `favorite_count` column type is `object`

# %% [markdown]
# #### Define
# * Change columns datatypes

# %% [markdown]
# #### Code

# %%
# To int
tweet_details.retweet_count = tweet_details.retweet_count.astype(int)

# To int
tweet_details.favorite_count = tweet_details.favorite_count.astype(int)

# %% [markdown]
# #### Test

# %%
tweet_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null object
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 55.2+ KB

# %% [markdown]
# **image_prediction:**
# - `tweet_id` column type is `int64` not `string`

# %% [markdown]
# #### Define
# * Change column type

# %% [markdown]
# #### Code

# %%
# To string
image_prediction.tweet_id = image_prediction.tweet_id.astype(str)

# %% [markdown]
# #### Test

# %%
image_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null object
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# ### Tidiness

# %% [markdown]
# **`archive`: Four variables in four columns `doggo`,`floofer`,`pupper`,`puppo`**

# %% [markdown]
# #### Define
# * Merging multiple dog stages

# %% [markdown]
# #### Code

# %%
archive.groupby(["doggo", "floofer", "pupper", "puppo"]).size().reset_index().rename(columns={0: "count"})
# Out:
#    doggo  floofer  pupper  puppo  count
# 0   None     None    None   None   1976
# 1   None     None    None  puppo     29
# 2   None     None  pupper   None    245
# 3   None  floofer    None   None      9
# 4  doggo     None    None   None     83
# 5  doggo     None    None  puppo      1
# 6  doggo     None  pupper   None     12
# 7  doggo  floofer    None   None      1

# %%
# Replace None with empty string
archive.doggo.replace('None', '', inplace=True)
archive.floofer.replace('None', '', inplace=True)
archive.pupper.replace('None', '', inplace=True)
archive.puppo.replace('None', '', inplace=True)

# %%
# Concatenating the values and separate them with comma ',' if there are multiple stages
archive['stage'] = archive.doggo + archive.floofer + archive.pupper + archive.puppo
archive.loc[archive.stage == 'doggopupper', 'stage'] = 'doggo,pupper'
archive.loc[archive.stage == 'doggopuppo', 'stage'] = 'doggo,puppo'
archive.loc[archive.stage == 'doggofloofer', 'stage'] = 'doggo,floofer'

# %%
# Drop columns doggo,floofer,pupper,puppo
archive.drop(columns=['doggo','floofer','pupper','puppo'], inplace=True)

# %% [markdown]
# #### Test

# %%
archive.query('stage != ""')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 9     890240255349198849                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 14    889531135344209921                    NaN                  NaN
# 29    886366144734445568                    NaN                  NaN
# 43    884162670584377345                    NaN                  NaN
# 46    883360690899218434                    NaN                  NaN
# 49    882762694511734784                    NaN                  NaN
# 56    881536004380872706                    NaN                  NaN
# 71    878776093423087618                    NaN                  NaN
# 78    877611172832227328                    NaN                  NaN
# 82    876838120628539392                    NaN                  NaN
# 92    874296783580663808                    NaN                  NaN
# 94    874012996292530176                    NaN                  NaN
# ...

# %%
archive.stage.value_counts()
# Out:
#                  1976
# pupper            245
# doggo              83
# puppo              29
# doggo,pupper       12
# floofer             9
# doggo,floofer       1
# doggo,puppo         1
# Name: stage, dtype: int64

# %% [markdown]
# **Merge archive_copy to tweet_details on tweet_id**

# %% [markdown]
# #### Define
# * Use Pandas merge for both tables `archive_copy` and `tweet_details_copy` on column `tweet_id`

# %% [markdown]
# #### Code

# %%
archive_copy = pd.merge(archive_copy, tweet_details_copy, on=['tweet_id'])

# %% [markdown]
# #### Test

# %%
archive_copy
# Out:
#                 tweet_id           timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56
# 1     892177421306343426 2017-08-01 00:17:27
# 2     891815181378084864 2017-07-31 00:18:03
# 3     891689557279858688 2017-07-30 15:58:51
# 4     891327558926688256 2017-07-29 16:00:24
# 5     891087950875897856 2017-07-29 00:08:17
# 6     890971913173991426 2017-07-28 16:27:12
# 7     890729181411237888 2017-07-28 00:22:40
# 8     890609185150312448 2017-07-27 16:25:51
# 9     890240255349198849 2017-07-26 15:59:51
# 10    890006608113172480 2017-07-26 00:31:25
# 11    889880896479866881 2017-07-25 16:11:53
# 12    889665388333682689 2017-07-25 01:55:32
# 13    889638837579907072 2017-07-25 00:10:02
# 14    889531135344209921 2017-07-24 17:02:04
# 15    889278841981685760 2017-07-24 00:19:32
# 16    888917238123831296 2017-07-23 00:22:39
# 17    888804989199671297 2017-07-22 16:56:37
# 18    888554962724278272 2017-07-22 00:23:06
# 19    888078434458587136 2017-07-20 16:49:33
# ...

# %% [markdown]
# ### Storing Cleaned Data

# %%
archive_copy.to_csv('twitter_archive_master.csv', index=False)
image_prediction_copy.to_csv('image_prediction_v1.csv', index=False)

# %%
# Test the saved files
archive = pd.read_csv('twitter_archive_master.csv')
image_prediction = pd.read_csv('image_prediction_v1.csv')

# %%
archive.head()
# Out:
#              tweet_id            timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56
# 1  892177421306343426  2017-08-01 00:17:27
# 2  891815181378084864  2017-07-31 00:18:03
# 3  891689557279858688  2017-07-30 15:58:51
# 4  891327558926688256  2017-07-29 16:00:24
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %%
archive.tail()
# Out:
#                 tweet_id            timestamp  \
# 2088  666049248165822465  2015-11-16 00:24:50
# 2089  666044226329800704  2015-11-16 00:04:52
# 2090  666033412701032449  2015-11-15 23:21:54
# 2091  666029285002620928  2015-11-15 23:05:30
# 2092  666020888022790149  2015-11-15 22:32:08
#
#                                                  source  \
# 2088  <a href="http://twitter.com/download/iphone" r...
# 2089  <a href="http://twitter.com/download/iphone" r...
# 2090  <a href="http://twitter.com/download/iphone" r...
# 2091  <a href="http://twitter.com/download/iphone" r...
# 2092  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 2088  Here we have a 1949 1st generation vulpix. Enj...
# 2089  This is a purebred Piers Morgan. Loves to Netf...
# 2090  Here is a very happy pup. Big fan of well-main...
# 2091  This is a western brown Mitsubishi terrier. Up...
# 2092  Here we have a Japanese Irish Setter. Lost eye...
#
# ...

# %%
image_prediction.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# ### Analysis & Visualization

# %%
archive.describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator  retweet_count  \
# count  2.093000e+03       2093.000000         2093.000000    2093.000000
# mean   7.364849e+17         12.190635           10.449594    2835.290014
# std    6.711077e+16         40.403492            6.651382    4696.198536
# min    6.660209e+17          0.000000            2.000000      16.000000
# 25%    6.768117e+17         10.000000           10.000000     644.000000
# 50%    7.095662e+17         11.000000           10.000000    1403.000000
# 75%    7.873980e+17         12.000000           10.000000    3285.000000
# max    8.924206e+17       1776.000000          170.000000   79515.000000
#
#        favorite_count
# count     2093.000000
# mean      8973.555662
# std      12193.630871
# min         81.000000
# 25%       2045.000000
# 50%       4195.000000
# 75%      11416.000000
# max     132810.000000

# %% [markdown]
# - We have 2093 tweets.
# - The mean of retweets is 2835.
# - The mean of favorites is 8973.
# - The maximum retweets is 79515.
# - The maximun favorites is 132810.

# %%
image_prediction.p1.value_counts()
# Out:
# golden_retriever             139
# Labrador_retriever            95
# Pembroke                      88
# Chihuahua                     79
# pug                           55
# chow                          41
# Samoyed                       40
# toy_poodle                    38
# Pomeranian                    38
# malamute                      29
# cocker_spaniel                27
# French_bulldog                26
# Chesapeake_Bay_retriever      23
# miniature_pinscher            22
# seat_belt                     21
# German_shepherd               20
# Siberian_husky                20
# Staffordshire_bullterrier     19
# web_site                      19
# teddy                         18
# Maltese_dog                   18
# Eskimo_dog                    18
# Shetland_sheepdog             18
# beagle                        17
# Rottweiler                    17
# Cardigan                      17
# Shih-Tzu                      17
# kuvasz                        16
# ...

# %% [markdown]
# - The most recognized images are for dog's breed **golden_retriever** with 139 image.
# - The second most recognized images are for dog's breed **Labrador_retriever** with 95 image.

# %%
# How many correct predictions for p1 algorithm
image_prediction.groupby(['p1_dog']).p1.count()
# Out:
# p1_dog
# False     529
# True     1480
# Name: p1, dtype: int64

# %%
# How many correct predictions for p2 algorithm
image_prediction.groupby(['p2_dog']).p2.count()
# Out:
# p2_dog
# False     509
# True     1500
# Name: p2, dtype: int64

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
arch = archive.copy()

# %%
# to plot based on each month of each year
arch.timestamp = [x[:7] for x in arch['timestamp']]
arch.head()
# Out:
#              tweet_id timestamp  \
# 0  892420643555336193   2017-08
# 1  892177421306343426   2017-08
# 2  891815181378084864   2017-07
# 3  891689557279858688   2017-07
# 4  891327558926688256   2017-07
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# ...

# %%
arch.groupby('timestamp').retweet_count.sum()
# Out:
# timestamp
# 2015-11    160952
# 2015-12    581632
# 2016-01    304553
# 2016-02    186298
# 2016-03    233415
# 2016-04     97674
# 2016-05    132613
# 2016-06    371879
# 2016-07    271731
# 2016-08    220630
# 2016-09    249528
# 2016-10    311031
# 2016-11    259787
# 2016-12    320273
# 2017-01    427323
# 2017-02    290423
# 2017-03    257986
# 2017-04    242027
# 2017-05    323109
# 2017-06    314276
# 2017-07    361755
# 2017-08     15367
# Name: retweet_count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(18,7))
locations = ['2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07',
          '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05',
          '2017-06', '2017-07', '2017-08']
heights = arch.groupby(['timestamp']).sum()['retweet_count']
labels = ['2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07',
          '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05',
          '2017-06', '2017-07', '2017-08']
plt.bar(locations, heights, tick_label=labels)
plt.title('Total Retweets per Month')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.legend()
plt.savefig('fig1.png');

# %%
fig, ax = plt.subplots(figsize=(18,7))
locations = ['2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07',
          '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05',
          '2017-06', '2017-07', '2017-08']
heights = arch.groupby(['timestamp']).sum()['favorite_count']
labels = ['2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07',
          '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05',
          '2017-06', '2017-07', '2017-08']
plt.bar(locations, heights, tick_label=labels)
plt.title('Total Favorites per Month')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.savefig('fig2.png')
plt.legend();

# %%
fig, ax = plt.subplots(figsize=(18,7))
locations = ['2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07',
          '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05',
          '2017-06', '2017-07', '2017-08']
heights = arch.groupby(['timestamp']).count()['tweet_id']
labels = ['2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07',
          '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05',
          '2017-06', '2017-07', '2017-08']
plt.bar(locations, heights, tick_label=labels)
plt.title('Total Tweets per Month')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.savefig('fig3.png')
plt.legend();
